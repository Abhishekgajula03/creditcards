# %%
pip install pandas numpy scikit-learn matplotlib seaborn streamlit joblib shap
# Out:
# Requirement already satisfied: pandas in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (2.2.5)
# Requirement already satisfied: scikit-learn in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: streamlit in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (1.44.1)
# Requirement already satisfied: joblib in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (1.4.2)
# Requirement already satisfied: shap in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (0.47.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: jinja2 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.36.0)
# Requirement already satisfied: colorama in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: six>=1.5 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abhishek\onedrive\desktop\credits\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('../data/german_credit_data.csv')

# Overview
df.info()
df.describe()
df.isnull().sum()

# Categorical column distribution
for col in ['Sex', 'Housing', 'Saving accounts', 'Checking account', 'Purpose']:
    sns.countplot(data=df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# Numeric distributions
sns.histplot(df['Age'], bins=20, kde=True)
sns.boxplot(x=df['Credit amount'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB
# <Axes: xlabel='Age', ylabel='Count'>
